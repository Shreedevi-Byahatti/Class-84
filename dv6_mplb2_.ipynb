# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreedevi-Byahatti/Class-84/blob/main/dv6_mplb2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Teacher will introduce data visualization through matplotlib**

# %% [markdown]
# **Teacher’s Activity**

# %%
x=list(range(1,6))
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
y=list(range(5,26,5))
print(y)
# Out:
# [5, 10, 15, 20, 25]

# %% [markdown]
# **Pyplot:** Most of the Matplotlib functions and methods lies under the pyplot submodule, and are usually imported under the plt alias

# %%
# import matplotlib pyplot as plt alias:
import matplotlib.pyplot as plt
# setting the size of display figure
plt.figure(figsize=(5,2))
# for ploting bar graph
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
# import matplotlib pyplot as plt alias:
import matplotlib.pyplot as plt
# setting the size of display figure
plt.figure(figsize=(5,2))
# Add labels and title
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is my x vs y")
# for ploting bar graph
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
Activities	=['School','Study','Play',	'Sleep','Others']
Time_spent =[6, 4, 1.5, 8, 4.5]
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))
# Add labels and title
plt.xlabel('Activities')
plt.ylabel('Time spent (in hrs)')
plt.title('Time spent by a child during a day')
# for ploting bar graph
plt.bar(Activities,Time_spent)
# Out:
# <BarContainer object of 5 artists>

# %%
Activities	=['School','Study','Play',	'Sleep','Others']
Time_spent =[6, 4, 1.5, 8, 4.5]
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))
# Add labels and title
plt.xlabel('Activities')
plt.ylabel('Time spent (in hrs)')
plt.title('Time spent by a child during a day')

# for ploting horizontal bar graph
plt.barh(Activities,Time_spent)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# labels will not change, so lets correct labels

# %%
Activities	=['School','Study','Play',	'Sleep','Others']
Time_spent =[6, 4, 1.5, 8, 4.5]
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))
# Add labels and title
plt.xlabel('Time spent (in hrs) ')
plt.ylabel('Activities')
plt.title('Time spent by a child during a day')

# for ploting horizontal bar graph
plt.barh(Activities,Time_spent)
# Out:
# <BarContainer object of 5 artists>

# %%
Activities	=['School','Study','Play',	'Sleep','Others']
Time_spent =[6, 4, 1.5, 8, 4.5]
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))
# Add labels and title
plt.xlabel('Activities')
plt.ylabel('Time spent (in hrs)')
plt.title('Time spent by a child during a day')
# for ploting bar graph
plt.bar(Activities,Time_spent, color ='#32a8a8',width = 0.2)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# **Student’s Activity**:

# %% [markdown]
# Let's consider a real-life example of data visualization using the following scenario:
#
# Scenario: A retail store wants to analyze its monthly sales data for the last year (12 months) to identify sales trends and make informed decisions.

# %%
'''Raw Data:

January: $15,000
February: $18,000
March: $20,500
April: $22,000
May: $19,500
June: $25,000
July: $28,000
August: $24,500
September: $23,000
October: $26,000
November: $30,000
December: $32,500'''
# Out:
# 'Raw Data:\n\nJanuary: $15,000\nFebruary: $18,000\nMarch: $20,500\nApril: $22,000\nMay: $19,500\nJune: $25,000\nJuly: $28,000\nAugust: $24,500\nSeptember: $23,000\nOctober: $26,000\nNovember: $30,000\nDecember: $32,500'

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))
# Sample data
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [15000, 18000, 20500, 22000, 19500, 25000, 28000, 24500, 23000, 26000, 30000, 32500]

# Create a line plot
plt.bar(months, sales, color='#ee82ee')

# Add labels and title
plt.xlabel('Months')
plt.ylabel('Sales Amount ($)')
plt.title('Monthly Sales Data')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))
# Sample data
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [15000, 18000, 20500, 22000, 19500, 25000, 28000, 24500, 23000, 26000, 30000, 32500]

# Create a line plot
plt.bar(months, sales, color='#ee82ee', width = 0.5)

# Add labels and title
plt.xlabel('Months')
plt.ylabel('Sales Amount ($)')
plt.title('Monthly Sales Data')

# for setting x lables vertical
plt.xticks(range(len(months)), months, rotation='vertical')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))

# Sample data
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [15000, 18000, 20500, 22000, 19500, 25000, 28000, 24500, 23000, 26000, 30000, 32500]

# Create a line plot
plt.bar(months, sales, color='#ee82ee', width = 0.75)

# Add labels and title
plt.xlabel('Months')
plt.ylabel('Sales Amount ($)')
plt.title('Monthly Sales Data')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **Teacher’s Activity - introduce new graphs**

# %% [markdown]
# **Student’s Activity**:
#
# Consider the monthly expenses of a household for various categories:
#
#
# categories = ['Housing', 'Utilities', 'Transportation', 'Groceries', 'Entertainment', 'Healthcare', 'Education', 'Miscellaneous']
#
# expenses = [1200, 300, 400, 500, 200, 150, 250, 100]
#
# You can use this data to create a bar graph to visualize the distribution of expenses across these categories.

# %%
import matplotlib.pyplot as plt

categories = ['Housing', 'Utilities', 'Transportation', 'Groceries', 'Entertainment', 'Healthcare', 'Education', 'Miscellaneous']
expenses = [1200, 300, 400, 500, 200, 150, 250, 100]

# Create a bar graph
plt.bar(categories, expenses, color='blue')

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Amount (USD)')
plt.title('Monthly Expenses of a Household')
#plt.title('Monthly Expenses of a Household \n This bar graph will visually represent the monthly expenses for each category,\n making it easy to compare and understand the distribution of expenditures within the household.')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()  # To avoid overlapping labels
plt.show()
#This bar graph will visually represent the monthly expenses for each category,
#making it easy to compare and understand the distribution of expenditures within the household.

# %% [markdown]
# #Histogram

# %%
import numpy as np
marks = np.random.randint(0, 100, 150)
marks
# Out:
# array([77, 51, 15,  1, 31, 98, 74, 30, 76, 56, 65, 79, 63, 19, 60, 84, 98,
#        35,  0, 49, 32, 91, 81, 41, 19, 71, 19, 11, 35, 16, 63, 79, 55, 36,
#        24, 20, 95, 22, 64, 63, 98,  5, 88, 83, 84, 26, 53, 47, 70, 37, 41,
#        30, 99, 71, 34, 95, 11, 55, 23, 84,  8, 97, 76,  6, 65, 33, 34,  6,
#        29, 19, 94, 99, 85, 30,  1,  2, 41, 27, 21, 31, 77, 46, 58, 94, 68,
#        80, 57, 19, 20, 49, 92, 14, 66, 84, 13, 51, 14, 45, 15, 82, 76, 85,
#        15, 50,  6, 93, 42, 34, 84, 72, 62, 11, 40, 81, 99,  1, 15,  3, 13,
#         7, 11, 67, 53, 86, 80, 41, 85, 42, 39, 91, 24, 33, 87, 12, 75, 50,
#        62, 35, 93, 32,  8, 32, 40, 28, 57, 41, 65, 73, 38, 95])

# %%
# Add labels and title
plt.xlabel('marks')
plt.ylabel('no. of students')
plt.title('no. of students vs marks')
# Create a histogram
plt.hist(marks)
# Add gridlines
plt.grid(True)

# %%
plt.hist(marks)
# Add gridlines
plt.grid(True)

# %%
plt.figure(figsize=(5,2))
import matplotlib.pyplot as plt

labels = 'S1', 'S2', 'S3'
sections = [70, 30, 100]

plt.pie(sections, labels=labels)

plt.title('Pie Chart Example')
plt.show()

# %%
plt.figure(figsize=(5,2))
import matplotlib.pyplot as plt

labels = 'S1', 'S2', 'S3'
sections = [70,30,100]

plt.pie(sections, labels=labels)

plt.axis('equal') # Try uncommenting this out.
plt.title('Pie Chart Example')
plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'S1', 'S2', 'S3'
sections = [70,30,100]
colors = ['c', 'g', 'y']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0.5),
        autopct = '%1.4f%%' )
plt.legend(title = "three sections")
plt.axis('equal')
plt.title('Pie Chart Example')
plt.show()

# %%
Activities	=['School','Study','Play',	'Sleep','Others']
Time_spent =[6, 4, 1.5, 8, 4.5]
colors = ['c', 'g', 'y','m', 'hotpink', '#32a8a8']

import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))

plt.pie(Time_spent, labels=Activities, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0.5,0.25,0.5),
        autopct = '%1.4f%%' )
plt.legend(title = "three sections")
plt.axis('equal')
plt.title('Pie Chart Example')
plt.show()

# %% [markdown]
# #Compare Plots

# %%
import matplotlib.pyplot as plt

x  = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="line L")
plt.plot(x, y2, label="line H")
plt.plot()

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Look at index 4 and 6, which demonstrate overlapping cases.
x1 = [1, 3, 4, 5, 6, 7, 9]
y1 = [4, 7, 2, 4, 7, 8, 3]

x2 = [2, 4, 6, 8, 10]
y2 = [5, 6, 2, 6, 2]

plt.bar(x1, y1, label="Blue Bar", color='b')
plt.bar(x2, y2, label="Green Bar", color='g')
plt.plot()

plt.xlabel("bar number")
plt.ylabel("bar height")
plt.title("Bar Chart Example")
plt.legend()
plt.show()

# %% [markdown]
# **changing order**

# %%
plt.bar(x2, y2, label="Green Bar", color='g')
plt.bar(x1, y1, label="Blue Bar", color='b')

plt.plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt

x1 = [2, 3, 4]
y1 = [5, 5, 5]

x2 = [1, 2, 3, 4, 5]
y2 = [2, 3, 2, 3, 4]
y3 = [6, 8, 7, 8, 7]

plt.scatter(x1, y1)
plt.scatter(x2, y2, marker='v', color='r')
plt.scatter(x2, y3, marker='^', color='m')
plt.title('Scatter Plot Example')
plt.show()

# %% [markdown]
# #subplots

# %%
plt.figure(figsize=(5,10))
plt.suptitle('2 subplots')

sub=['maths', 'science', 'lang1', 'lang2']
m1=[70,90,50,60]
m2=[60,70,80,90]

plt.subplot(2, 1, 1)
plt.bar(sub, m1, color ='c')
plt.title('subplot 1')
plt.ylabel('marks')

plt.subplot(2, 1, 2)
plt.bar(sub, m2, color ='m')
plt.title('subplot 2')
plt.xlabel('subjects')
plt.ylabel('marks')

plt.show()

# %%
plt.figure(figsize=(10,5))
plt.suptitle('2 subplots')

sub=['maths', 'science', 'lang1', 'lang2']
m1=[70,90,50,60]
m2=[60,70,80,90]

plt.subplot(1, 2, 1)
plt.bar(sub, m1, color ='c')
plt.title('subplot 1')
plt.ylabel('marks')

plt.subplot(1, 2, 2)
plt.bar(sub, m2, color ='m')
plt.title('subplot 2')
plt.xlabel('subjects')
plt.ylabel('marks')

plt.show()

# %%
import matplotlib.pyplot as plt

Activities	=['School','Study','Play',	'Sleep','Others']
Time_spent =[6, 4, 1.5, 8, 4.5]
colors = ['c', 'g', 'y','m', 'hotpink', '#32a8a8']

# Create a figure with subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

# Plot on each subplot
axs[0, 0].plot(Activities, Time_spent)
axs[0, 0].set_title('Subplot 1 line graph')

axs[0, 1].scatter(Activities, Time_spent)
axs[0, 1].set_title('Subplot 2 scatter graph')

axs[1, 0].bar(Activities, Time_spent)
axs[1, 0].set_title('Subplot 3 bar graph')

axs[1, 1].pie(Time_spent, labels=Activities, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0.5,0.25,0.5),
        autopct = '%1.1f%%' )
axs[1, 1].set_title('Subplot 4 pie chart')

# Adjust layout
plt.tight_layout()

# Show the subplots
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(5, 4))

# Plot on each subplot
axs[0, 0].plot([1, 2, 3], [4, 5, 6])
axs[0, 0].set_title('Subplot 1')

axs[0, 1].scatter([2, 4, 6], [7, 3, 9])
axs[0, 1].set_title('Subplot 2')

axs[1, 0].bar(['A', 'B', 'C'], [10, 8, 12])
axs[1, 0].set_title('Subplot 3')

axs[1, 1].hist([5, 6, 7, 5, 8, 9, 7, 6, 7])
axs[1, 1].set_title('Subplot 4')

# Adjust layout
plt.tight_layout()

# Show the subplots
plt.show()
